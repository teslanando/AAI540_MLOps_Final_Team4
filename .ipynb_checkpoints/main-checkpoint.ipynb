# %%
import boto3
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import LabelEncoder
import sagemaker
import time
import sagemaker
import pandas as pd
from sagemaker import get_execution_role
import numpy as np
import matplotlib.pyplot as plt
import os
import tarfile
from IPython.display import display, HTML
import random
import matplotlib.image as mpimg
import io
from PIL import Image
import requests
from sagemaker.feature_store.feature_definition import FeatureDefinition, FeatureTypeEnum
from sagemaker.feature_store.feature_group import FeatureGroup
from time import gmtime, strftime
import boto3
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import LabelEncoder
import sagemaker
from sagemaker.estimator import Estimator
from sagemaker.serializers import CSVSerializer
from sagemaker.deserializers import JSONDeserializer
from sagemaker.predictor import Predictor
from sklearn.metrics import classification_report

# %%
# Create S3 Bucket
session = boto3.session.Session()
region = session.region_name
sagemaker_session = sagemaker.Session()
bucket = sagemaker_session.default_bucket()

s3 = boto3.Session().client(service_name="s3", region_name=region)

# %%
print("Default bucket: {}".format(bucket))
# Out:
# Default bucket: sagemaker-us-east-1-284000663973

# %%
sess = sagemaker.Session()
bucket = sess.default_bucket()
role = sagemaker.get_execution_role()
region = boto3.Session().region_name
account_id = boto3.client("sts").get_caller_identity().get("Account")

sm = boto3.Session().client(service_name="sagemaker", region_name=region)

# %%
s3_private_path = "s3://{}/data".format(bucket)
print(s3_private_path)
# Out:
# s3://sagemaker-us-east-1-284000663973/data

# %%
# !aws s3 cp "./data" $s3_private_path/ --recursive
# Out:
# upload: data/benign/1003.jpg to s3://sagemaker-us-east-1-284000663973/data/benign/1003.jpg
# upload: data/benign/1013.jpg to s3://sagemaker-us-east-1-284000663973/data/benign/1013.jpg
# upload: data/benign/1.jpg to s3://sagemaker-us-east-1-284000663973/data/benign/1.jpg
# upload: data/benign/10.jpg to s3://sagemaker-us-east-1-284000663973/data/benign/10.jpg
# upload: data/benign/1018.jpg to s3://sagemaker-us-east-1-284000663973/data/benign/1018.jpg
# upload: data/benign/1033.jpg to s3://sagemaker-us-east-1-284000663973/data/benign/1033.jpg
# upload: data/benign/1061.jpg to s3://sagemaker-us-east-1-284000663973/data/benign/1061.jpg
# upload: data/benign/1006.jpg to s3://sagemaker-us-east-1-284000663973/data/benign/1006.jpg
# upload: data/benign/1055.jpg to s3://sagemaker-us-east-1-284000663973/data/benign/1055.jpg
# upload: data/benign/1023.jpg to s3://sagemaker-us-east-1-284000663973/data/benign/1023.jpg
# upload: data/benign/1070.jpg to s3://sagemaker-us-east-1-284000663973/data/benign/1070.jpg
# upload: data/benign/1029.jpg to s3://sagemaker-us-east-1-284000663973/data/benign/1029.jpg
# upload: data/benign/1074.jpg to s3://sagemaker-us-east-1-284000663973/data/benign/1074.jpg
# upload: data/benign/1019.jpg to s3://sagemaker-us-east-1-284000663973/data/benign/1019.jpg
# upload: data/benign/1077.jpg to s3://sagemaker-us-east-1-284000663973/data/benign/1077.jpg
# upload: data/benign/1042.jpg to s3://sagemaker-us-east-1-284000663973/data/benign/1042.jpg
# upload: data/benign/1080.jpg to s3://sagemaker-us-east-1-284000663973/data/benign/1080.jpg
# upload: data/benign/1088.jpg to s3://sagemaker-us-east-1-284000663973/data/benign/1088.jpg
# upload: data/benign/1034.jpg to s3://sagemaker-us-east-1-284000663973/data/benign/1034.jpg
# upload: data/benign/1112.jpg to s3://sagemaker-us-east-1-284000663973/data/benign/1112.jpg
# upload: data/benign/1110.jpg to s3://sagemaker-us-east-1-284000663973/data/benign/1110.jpg
# upload: data/benign/1118.jpg to s3://sagemaker-us-east-1-284000663973/data/benign/1118.jpg
# upload: data/benign/1115.jpg to s3://sagemaker-us-east-1-284000663973/data/benign/1115.jpg
# upload: data/benign/1087.jpg to s3://sagemaker-us-east-1-284000663973/data/benign/1087.jpg
# upload: data/benign/11.jpg to s3://sagemaker-us-east-1-284000663973/data/benign/11.jpg
# upload: data/benign/1125.jpg to s3://sagemaker-us-east-1-284000663973/data/benign/1125.jpg
# upload: data/benign/1130.jpg to s3://sagemaker-us-east-1-284000663973/data/benign/1130.jpg
# upload: data/benign/1025.jpg to s3://sagemaker-us-east-1-284000663973/data/benign/1025.jpg
# upload: data/benign/1134.jpg to s3://sagemaker-us-east-1-284000663973/data/benign/1134.jpg
# upload: data/benign/1126.jpg to s3://sagemaker-us-east-1-284000663973/data/benign/1126.jpg
# upload: data/benign/105.jpg to s3://sagemaker-us-east-1-284000663973/data/benign/105.jpg
# upload: data/benign/1143.jpg to s3://sagemaker-us-east-1-284000663973/data/benign/1143.jpg
# upload: data/benign/1139.jpg to s3://sagemaker-us-east-1-284000663973/data/benign/1139.jpg
# upload: data/benign/1146.jpg to s3://sagemaker-us-east-1-284000663973/data/benign/1146.jpg
# upload: data/benign/1044.jpg to s3://sagemaker-us-east-1-284000663973/data/benign/1044.jpg
# upload: data/benign/1135.jpg to s3://sagemaker-us-east-1-284000663973/data/benign/1135.jpg
# upload: data/benign/1151.jpg to s3://sagemaker-us-east-1-284000663973/data/benign/1151.jpg
# upload: data/benign/1170.jpg to s3://sagemaker-us-east-1-284000663973/data/benign/1170.jpg
# upload: data/benign/1173.jpg to s3://sagemaker-us-east-1-284000663973/data/benign/1173.jpg
# upload: data/benign/1166.jpg to s3://sagemaker-us-east-1-284000663973/data/benign/1166.jpg
# upload: data/benign/1155.jpg to s3://sagemaker-us-east-1-284000663973/data/benign/1155.jpg
# upload: data/benign/1092.jpg to s3://sagemaker-us-east-1-284000663973/data/benign/1092.jpg
# upload: data/benign/1177.jpg to s3://sagemaker-us-east-1-284000663973/data/benign/1177.jpg
# upload: data/benign/1208.jpg to s3://sagemaker-us-east-1-284000663973/data/benign/1208.jpg
# upload: data/benign/1200.jpg to s3://sagemaker-us-east-1-284000663973/data/benign/1200.jpg
# upload: data/benign/1215.jpg to s3://sagemaker-us-east-1-284000663973/data/benign/1215.jpg
# upload: data/benign/1203.jpg to s3://sagemaker-us-east-1-284000663973/data/benign/1203.jpg
# upload: data/benign/1180.jpg to s3://sagemaker-us-east-1-284000663973/data/benign/1180.jpg
# upload: data/benign/1214.jpg to s3://sagemaker-us-east-1-284000663973/data/benign/1214.jpg
# upload: data/benign/119.jpg to s3://sagemaker-us-east-1-284000663973/data/benign/119.jpg
# upload: data/benign/1183.jpg to s3://sagemaker-us-east-1-284000663973/data/benign/1183.jpg
# upload: data/benign/12.jpg to s3://sagemaker-us-east-1-284000663973/data/benign
jpg to s3://sagemaker-us-east-1-284000663973/data/malignant/986.jpg
# upload: data/malignant/99.jpg to s3://sagemaker-us-east-1-284000663973/data/malignant/99.jpg
# upload: data/malignant/985.jpg to s3://sagemaker-us-east-1-284000663973/data/malignant/985.jpg
# upload: data/malignant/989.jpg to s3://sagemaker-us-east-1-284000663973/data/malignant/989.jpg
# upload: data/malignant/981.jpg to s3://sagemaker-us-east-1-284000663973/data/malignant/981.jpg
# upload: data/malignant/990.jpg to s3://sagemaker-us-east-1-284000663973/data/malignant/990.jpg
# upload: data/malignant/995.jpg to s3://sagemaker-us-east-1-284000663973/data/malignant/995.jpg
# upload: data/malignant/987.jpg to s3://sagemaker-us-east-1-284000663973/data/malignant/987.jpg
# upload: data/malignant/993.jpg to s3://sagemaker-us-east-1-284000663973/data/malignant/993.jpg
# upload: data/malignant/991.jpg to s3://sagemaker-us-east-1-284000663973/data/malignant/991.jpg
# upload: data/malignant/992.jpg to s3://sagemaker-us-east-1-284000663973/data/malignant/992.jpg
# upload: data/malignant/998.jpg to s3://sagemaker-us-east-1-284000663973/data/malignant/998.jpg
# upload: data/malignant/997.jpg to s3://sagemaker-us-east-1-284000663973/data/malignant/997.jpg
# upload: data/malignant/994.jpg to s3://sagemaker-us-east-1-284000663973/data/malignant/994.jpg
# upload: data/malignant/996.jpg to s3://sagemaker-us-east-1-284000663973/data/malignant/996.jpg
# upload: data/malignant/999.jpg to s3://sagemaker-us-east-1-284000663973/data/malignant/999.jpg

# %%
# !aws s3 ls $s3_private_path/
# Out:
#                            PRE /
#                            PRE benign/
#                            PRE malignant/
#                            PRE output/
#                            PRE test/
#                            PRE train/
#                            PRE validation/

# %%
display(
    HTML(
        '<b>Review <a target="blank" href="https://s3.console.aws.amazon.com/s3/buckets/sagemaker-{}-{}/data/?region={}&tab=overview">S3 Bucket</a></b>'.format(
            region, account_id, region
        )
    )
)
# Out:
# <b>Review <a target="blank" href="https://s3.console.aws.amazon.com/s3/buckets/sagemaker-us-east-1-284000663973/data/?region=us-east-1&tab=overview">S3 Bucket</a></b>

# %% [markdown]
# # EDA

# %%
data_prefix = "data/"  # Ensure this points to the root of your data folder

# Create a client to interact with S3
s3 = boto3.client('s3')

# Initialize lists to store image paths and labels
image_paths = []
labels = []

# Initialize pagination for listing all objects
paginator = s3.get_paginator('list_objects_v2')
pages = paginator.paginate(Bucket=bucket, Prefix=data_prefix)

# Collect image file paths and labels based on S3 keys
for page in pages:
    for obj in page.get('Contents', []):
        if obj['Key'].endswith('.jpg') or obj['Key'].endswith('.png'):
            image_path = f"s3://{bucket}/{obj['Key']}"
            image_paths.append(image_path)
            
            # Assuming folder structure is data/class_name/image.jpg
            label = obj['Key'].split('/')[-2]
            labels.append(label)

# Create a DataFrame to store image paths and labels
df = pd.DataFrame({'image_path': image_paths, 'label': labels})

# Check the distribution of classes
class_distribution = df['label'].value_counts()
print("Class distribution:")
print(class_distribution)

# Plot the class distribution
class_distribution.plot(kind='bar')
plt.title('Class Distribution')
plt.xlabel('Class')
plt.ylabel('Number of Images')
plt.show()
# Out:
# Class distribution:
# label
# malignant    1130
# benign        755
# Name: count, dtype: int64

# %%
# Use boto3 to access the S3 images
s3 = boto3.client('s3')

def load_image_from_s3(s3_url):
    # Parse the S3 URL
    bucket_name = s3_url.split('/')[2].split('.')[0]
    key = '/'.join(s3_url.split('/')[3:])

    # Get the image object from S3
    obj = s3.get_object(Bucket=bucket_name, Key=key)
    
    # Read the image content and return it as an Image object
    img_data = obj['Body'].read()
    img = Image.open(io.BytesIO(img_data))
    
    return img

def show_sample_images(df, num_samples=5):
    classes = df['label'].unique()
    fig, axs = plt.subplots(len(classes), num_samples, figsize=(num_samples*3, len(classes)*3))

    for i, cls in enumerate(classes):
        cls_df = df[df['label'] == cls]
        samples = cls_df.sample(num_samples)
        for j, (_, row) in enumerate(samples.iterrows()):
            img = load_image_from_s3(row['image_path'])  # Load image from S3
            axs[i, j].imshow(img)
            axs[i, j].axis('off')
            if j == 0:
                axs[i, j].set_ylabel(cls, size='large')

    plt.tight_layout()
    plt.show()

# Show sample images
show_sample_images(df)

# %% [markdown]
# # Feature Engineering | Feature Store | Feature Group

# %%
feature_store_session = sagemaker_session

# Define the feature group
feature_group_name = 'skin-cancer-feature-group' + strftime('%d-%H-%M-%S', gmtime())
feature_group = FeatureGroup(name=feature_group_name, sagemaker_session=feature_store_session)

# Function to extract features from each image
def extract_features(row):
    # Read image from S3
    key_path = '/'.join(row['image_path'].split('/')[3:])
    s3_object = s3.get_object(Bucket=bucket, Key=key_path)
    img = Image.open(io.BytesIO(s3_object['Body'].read()))
    img_array = np.array(img)

    # Extract image features
    height, width = img.size
    mean_pixel_value = img_array.mean()

    return pd.Series({
        'image_path': row['image_path'],
        'label': row['label'],
        'height': height,
        'width': width,
        'mean_pixel_value': mean_pixel_value
    })

# Assume df is your initial DataFrame containing the image paths and labels
features_df = df.apply(extract_features, axis=1)

# Set up event time and record identifier
record_identifier_name = 'image_path'
event_time_feature_name = 'event_time'

# Ensure the event time is in the correct ISO-8601 format with timezone
features_df[event_time_feature_name] = pd.to_datetime('now', utc=True).strftime('%Y-%m-%dT%H:%M:%S.%f')[:-3] + 'Z'

# Create the feature group
feature_group.load_feature_definitions(data_frame=features_df)

# Create the feature group in SageMaker Feature Store
feature_group.create(
    s3_uri=f's3://{bucket}/{data_prefix}/feature-store',
    record_identifier_name=record_identifier_name,
    event_time_feature_name=event_time_feature_name,
    role_arn=role,
    enable_online_store=True
)

# Function to check the status of the feature group
def wait_for_feature_group_creation(feature_group):
    status = 'Creating'
    while status not in ['Created', 'CreateFailed']:
        description = feature_group.describe()
        status = description['FeatureGroupStatus']
        if status == 'Created':
            print(f"Feature group '{feature_group_name}' successfully created.")
            break
        elif status == 'CreateFailed':
            raise Exception(f"Feature group '{feature_group_name}' creation failed.")
        print(f"Waiting for feature group '{feature_group_name}' creation. Current status: {status}")
        time.sleep(10)  # Check every 10 seconds

# Wait for the feature group to be created
wait_for_feature_group_creation(feature_group)

# Ingest the DataFrame directly into the Feature Store
feature_group.ingest(data_frame=features_df, max_workers=5, wait=True)

print(f"Features successfully ingested into Feature Group: {feature_group_name}")
# Out:
# Waiting for feature group 'skin-cancer-feature-group13-21-25-27' creation. Current status: Creating
# Waiting for feature group 'skin-cancer-feature-group13-21-25-27' creation. Current status: Creating
# Waiting for feature group 'skin-cancer-feature-group13-21-25-27' creation. Current status: Creating
# Waiting for feature group 'skin-cancer-feature-group13-21-25-27' creation. Current status: Creating
# Feature group 'skin-cancer-feature-group13-21-25-27' successfully created.
# Features successfully ingested into Feature Group: skin-cancer-feature-group13-21-25-27

# %% [markdown]
# # Benchmark Model

# %%
from sklearn.model_selection import train_test_split

# First, split off production data (40%)
train_val_df, prod_df = train_test_split(features_df, test_size=0.4, stratify=features_df['label'], random_state=42)

# Then split the remaining data
train_df, temp_df = train_test_split(train_val_df, test_size=0.2, stratify=train_val_df['label'], random_state=42)
val_df, test_df = train_test_split(temp_df, test_size=0.5, stratify=temp_df['label'], random_state=42)

# Verify the splits
print(f"Training set: {len(train_df)} samples")
print(f"Validation set: {len(val_df)} samples")
print(f"Test set: {len(test_df)} samples")
print(f"Production set: {len(prod_df)} samples")
# Out:
# Training set: 904 samples
# Validation set: 113 samples
# Test set: 114 samples
# Production set: 754 samples

# %%
# Select simple features
benchmark_features = ['mean_pixel_value']

# Prepare datasets
X_train = train_df[benchmark_features]
y_train = train_df['label']

X_val = val_df[benchmark_features]
y_val = val_df['label']

X_test = test_df[benchmark_features]
y_test = test_df['label']

# %%
# Encode labels
le = LabelEncoder()
y_train_enc = le.fit_transform(y_train)
y_val_enc = le.transform(y_val)
y_test_enc = le.transform(y_test)

# Train logistic regression benchmark model
benchmark_model = LogisticRegression()
benchmark_model.fit(X_train, y_train_enc)

# Evaluate on validation set
val_score = benchmark_model.score(X_val, y_val_enc)
print(f"Validation Accuracy of Benchmark Model: {val_score}")
# Out:
# Validation Accuracy of Benchmark Model: 0.5929203539823009

# %% [markdown]
# ## Improved Model

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.datasets import dump_svmlight_file

# Encoding labels as numbers
le = LabelEncoder()
y_train_encoded = le.fit_transform(train_df['label'])
y_val_encoded = le.transform(val_df['label'])
y_test_encoded = le.transform(test_df['label'])

# Select features for the LIBSVM format (excluding 'label' and non-feature columns)
features = train_df.drop(['label', 'image_path', 'event_time'], axis=1)

# Save the datasets in LIBSVM format
dump_svmlight_file(features, y_train_encoded, 'train.libsvm')
dump_svmlight_file(val_df[features.columns], y_val_encoded, 'validation.libsvm')
dump_svmlight_file(test_df[features.columns], y_test_encoded, 'test.libsvm')

# Upload to S3
s3_resource = boto3.resource('s3')
s3_resource.Bucket(bucket).Object('data/train/train.libsvm').upload_file('train.libsvm')
s3_resource.Bucket(bucket).Object('data/validation/validation.libsvm').upload_file('validation.libsvm')
s3_resource.Bucket(bucket).Object('data/test/test.libsvm').upload_file('test.libsvm')

# Define the S3 paths for the LIBSVM files
s3_train_path = f's3://{bucket}/data/train/train.libsvm'
s3_val_path = f's3://{bucket}/data/validation/validation.libsvm'
s3_test_path = f's3://{bucket}/data/test/test.libsvm'

# Configure the Estimator
xgboost_estimator = Estimator(
    image_uri=sagemaker.image_uris.retrieve("xgboost", region, version="1.5-1"),
    role=role,
    instance_count=1,
    instance_type='ml.m5.large',
    output_path=f's3://{bucket}/data/output',
    hyperparameters={
        'objective': 'binary:logistic',
        'num_round': 100
    }
)

# Start training
xgboost_estimator.fit({'train': s3_train_path, 'validation': s3_val_path})
# Out:
# INFO:sagemaker.image_uris:Ignoring unnecessary instance type: None.
# INFO:sagemaker:Creating training-job with name: sagemaker-xgboost-2024-10-13-21-37-43-571
# 2024-10-13 21:37:43 Starting - Starting the training job...
# 2024-10-13 21:37:59 Starting - Preparing the instances for training...
# 2024-10-13 21:38:30 Downloading - Downloading input data......
# 2024-10-13 21:39:16 Downloading - Downloading the training image...
# 2024-10-13 21:40:12 Training - Training image download completed. Training in progress.
# 2024-10-13 21:40:12 Uploading - Uploading generated training model./miniconda3/lib/python3.8/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# [2024-10-13 21:40:07.396 ip-10-0-201-208.ec2.internal:7 INFO utils.py:28] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2024-10-13 21:40:07.417 ip-10-0-201-208.ec2.internal:7 INFO profiler_config_parser.py:111] User has disabled profiler.
# [2024-10-13:21:40:07:INFO] Imported framework sagemaker_xgboost_container.training
# [2024-10-13:21:40:07:INFO] Failed to parse hyperparameter objective value binary:logistic to Json.
# Returning the value itself
# [2024-10-13:21:40:07:INFO] No GPUs detected (normal if no gpus installed)
# [2024-10-13:21:40:07:INFO] Running XGBoost Sagemaker in algorithm mode
# [2024-10-13:21:40:07:INFO] Determined 0 GPU(s) available on the instance.
# [2024-10-13:21:40:07:INFO] files path: /opt/ml/input/data/train
# [2024-10-13:21:40:07:INFO] files path: /opt/ml/input/data/validation
# [2024-10-13:21:40:07:INFO] Single node training.
# [2024-10-13:21:40:07:INFO] Train matrix has 904 rows and 3 columns
# [2024-10-13:21:40:07:INFO] Validation matrix has 113 rows
# [2024-10-13 21:40:07.811 ip-10-0-201-208.ec2.internal:7 INFO json_config.py:92] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2024
# [97]#011train-logloss:0.43500#011validation-logloss:0.70291
# [98]#011train-logloss:0.43450#011validation-logloss:0.70462
# [99]#011train-logloss:0.43427#011validation-logloss:0.70449
#
# 2024-10-13 21:40:25 Completed - Training job completed
# Training seconds: 115
# Billable seconds: 115

# %% [markdown]
# # Endpoint creation | Model Deployment

# %%
# 1. Deploy the model to create an endpoint
endpoint_name = 'xgboost-skin-cancer-prediction'
predictor = xgboost_estimator.deploy(
    initial_instance_count=1,
    instance_type='ml.m4.xlarge',
    endpoint_name=endpoint_name,
    serializer=CSVSerializer(),
    deserializer=JSONDeserializer()
)
# Out:
# INFO:sagemaker:Creating model with name: sagemaker-xgboost-2024-10-13-22-14-21-782
# INFO:sagemaker:Creating endpoint-config with name xgboost-skin-cancer-prediction
# INFO:sagemaker:Creating endpoint with name xgboost-skin-cancer-prediction
# -------!

# %%
def extract_prediction(result):
    return int(result['score'] > 0.5)  # Use the correct key 'score' to extract the prediction

# Modify the model_predict function to return the first prediction directly
def model_predict(data, predictor):
    payload = ','.join(map(str, data))
    prediction = predictor.predict(payload)
    return prediction['predictions'][0]  # This returns the first prediction in the list

# Use the modified functions to make predictions on your test data
predictions = [extract_prediction(model_predict(row, predictor)) for row in test_data]

# Since the predictions are already binary (0 or 1), you can directly compare them with the encoded labels
encoder = LabelEncoder()
true_labels_encoded = encoder.fit_transform(test_df['label'])  # Ensure this column contains the correct labels

# Evaluate predictions
from sklearn.metrics import classification_report
print(classification_report(true_labels_encoded, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.44      0.30      0.36        46
#            1       0.61      0.74      0.67        68
#
#     accuracy                           0.56       114
#    macro avg       0.52      0.52      0.51       114
# weighted avg       0.54      0.56      0.54       114

# %% [markdown]
# # Compare Against Benchmark Model

# %%
# Get predictions for the logistic regression model
y_pred_benchmark = benchmark_model.predict(X_test_benchmark)
y_pred_benchmark_prob = benchmark_model.predict_proba(X_test_benchmark)[:, 1]
xgboost_predictions = predictor.predict(X_test_benchmark.to_numpy())
y_pred_xgboost = [int(round(p['score'])) for p in xgboost_predictions['predictions']]

# Calculate metrics
metrics = {
    'Accuracy': (accuracy_score(y_test_enc, y_pred_benchmark), accuracy_score(y_test_enc, y_pred_xgboost)),
    'Precision': (precision_score(y_test_enc, y_pred_benchmark), precision_score(y_test_enc, y_pred_xgboost)),
    'Recall': (recall_score(y_test_enc, y_pred_benchmark), recall_score(y_test_enc, y_pred_xgboost)),
    'F1 Score': (f1_score(y_test_enc, y_pred_benchmark), f1_score(y_test_enc, y_pred_xgboost))
}

# Create bar plots for each metric
fig, ax = plt.subplots(2, 2, figsize=(12, 10))
ax = ax.ravel()

for i, (metric, values) in enumerate(metrics.items()):
    ax[i].bar(['Logistic Regression', 'XGBoost'], values, color=['blue', 'green'])
    ax[i].set_title(f'{metric}')
    ax[i].set_ylim(0, 1)
    ax[i].set_ylabel('Score')

plt.tight_layout()
plt.show()

# %%
# Clean up
# sagemaker.Session().delete_endpoint(predictor.endpoint_name)

# %% [markdown]
# # Model Monitoring and Reports

# %%
# TODO

'''
Implement model monitors on your ML system.
Implement data monitors on your ML system.
Implement infrastructure monitors on your ML system.
Create a monitoring dashboard for your ML endpoint/job on Cloudwatch
Generate model and data reports on SageMaker.
Update and post the tracker to the Team Project Update.

# %% [markdown]
# # CI/CD
